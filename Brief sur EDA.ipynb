# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/home/adoumadji/Bureau/Brief/B2/data.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  index      company   body-style  wheel-base  length  \
# 0           0      0  alfa-romero  convertible        88.6   168.8
# 1           1      1  alfa-romero  convertible        88.6   168.8
# 2           2      2  alfa-romero    hatchback        94.5   171.2
# 3           3      3         audi        sedan        99.8   176.6
# 4           4      4         audi        sedan        99.4   176.6
#
#   engine-type num-of-cylinders  horsepower  average-mileage    price
# 0        dohc             four         111               21  13495.0
# 1        dohc             four         111               21  16500.0
# 2        ohcv              six         154               19  16500.0
# 3         ohc             four         102               24  13950.0
# 4         ohc             five         115               18  17450.0

# %%
df.shape
# Out:
# (58, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58 entries, 0 to 57
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        58 non-null     int64
#  1   index             58 non-null     int64
#  2   company           58 non-null     object
#  3   body-style        58 non-null     object
#  4   wheel-base        58 non-null     float64
#  5   length            58 non-null     float64
#  6   engine-type       58 non-null     object
#  7   num-of-cylinders  58 non-null     object
#  8   horsepower        58 non-null     int64
#  9   average-mileage   58 non-null     int64
#  10  price             58 non-null     float64
# dtypes: float64(3), int64(4), object(4)
# memory usage: 5.1+ KB

# %%
df.describe()
# Out:
#        Unnamed: 0      index  wheel-base      length  horsepower  \
# count   58.000000  58.000000   58.000000   58.000000   58.000000
# mean    28.500000  40.827586   98.620690  173.646552  106.051724
# std     16.886879  25.865467    6.810589   14.005616   48.915402
# min      0.000000   0.000000   88.400000  141.100000   48.000000
# 25%     14.250000  17.250000   94.500000  165.300000   68.000000
# 50%     28.500000  41.000000   96.400000  171.450000  100.000000
# 75%     42.750000  60.000000  101.800000  182.775000  122.500000
# max     57.000000  88.000000  120.900000  208.100000  262.000000
#
#        average-mileage         price
# count        58.000000     58.000000
# mean         25.534483  15387.000000
# std           7.932203  11320.259841
# min          13.000000   5151.000000
# 25%          19.000000   6808.500000
# 50%          24.500000  11095.000000
# 75%          31.000000  18120.500000
# max          47.000000  45400.000000

# %%
#Nétoyage des données

# %%
#Recherche des doublons
df.duplicated().sum()
# Out:
# 0

# %%
#Decouverte des données manquantes
df.isnull().sum()
# Out:
# Unnamed: 0          0
# index               0
# company             0
# body-style          0
# wheel-base          0
# length              0
# engine-type         0
# num-of-cylinders    0
# horsepower          0
# average-mileage     0
# price               0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'index', 'company', 'body-style', 'wheel-base', 'length',
#        'engine-type', 'num-of-cylinders', 'horsepower', 'average-mileage',
#        'price'],
#       dtype='object')

# %%
df.head()
# Out:
#    Unnamed: 0  index      company   body-style  wheel-base  length  \
# 0           0      0  alfa-romero  convertible        88.6   168.8
# 1           1      1  alfa-romero  convertible        88.6   168.8
# 2           2      2  alfa-romero    hatchback        94.5   171.2
# 3           3      3         audi        sedan        99.8   176.6
# 4           4      4         audi        sedan        99.4   176.6
#
#   engine-type num-of-cylinders  horsepower  average-mileage    price
# 0        dohc             four         111               21  13495.0
# 1        dohc             four         111               21  16500.0
# 2        ohcv              six         154               19  16500.0
# 3         ohc             four         102               24  13950.0
# 4         ohc             five         115               18  17450.0

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'index', 'company', 'body-style', 'wheel-base', 'length',
#        'engine-type', 'num-of-cylinders', 'horsepower', 'average-mileage',
#        'price'],
#       dtype='object')

# %%
deleted_columns=['Unnamed: 0','index']

# %%
df.drop(deleted_columns,axis=1, inplace=True)

# %%
#Analyse exploratd

# %% [markdown]
# # selection de données

# %%
df[['body-style', 'wheel-base', 'length', 'engine-type','num-of-cylinders', 'horsepower','average-mileage','price' ]]
# Out:
#      body-style  wheel-base  length engine-type num-of-cylinders  horsepower  \
# 0   convertible        88.6   168.8        dohc             four         111
# 1   convertible        88.6   168.8        dohc             four         111
# 2     hatchback        94.5   171.2        ohcv              six         154
# 3         sedan        99.8   176.6         ohc             four         102
# 4         sedan        99.4   176.6         ohc             five         115
# 5         sedan        99.8   177.3         ohc             five         110
# 6         wagon       105.8   192.7         ohc             five         110
# 7         sedan       101.2   176.8         ohc             four         101
# 8         sedan       101.2   176.8         ohc             four         101
# 9         sedan       101.2   176.8         ohc              six         121
# 10        sedan       103.5   189.0         ohc              six         182
# ...
